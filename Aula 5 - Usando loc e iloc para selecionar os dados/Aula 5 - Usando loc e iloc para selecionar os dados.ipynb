# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html

# %%
# Importando o pandas
import pandas as pd

# %%
# Importando os dados do arquivo excel
df = pd.read_excel("Dados.xlsx")

# %%
# Usando o loc
# df.loc[4:6] - Linhas
# df.loc[[1, 3, 4]]
df.loc[4:6, "NameStyle":"LastName"]
# Out:
#    NameStyle Title FirstName MiddleName  LastName
# 4          0   Ms.      Gail          A  Erickson
# 5          0   Mr.    Jossef          H  Goldberg
# 6          0   NaN     Dylan          A    Miller

# %%
# Usando o iloc
df.iloc[[2, 6], [True, True]]
# Out:
#    BusinessEntityID PersonType
# 2                 3         EM
# 6                 7         EM

# %%
df.head()
# Out:
#    BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 0                 1         EM          0   NaN       Ken          J
# 1                 2         EM          0   NaN     Terri        Lee
# 2                 3         EM          0   NaN   Roberto        NaN
# 3                 4         EM          0   NaN       Rob        NaN
# 4                 5         EM          0   Ms.      Gail          A
#
#      LastName Suffix  EmailPromotion
# 0     Sánchez    NaN               0
# 1       Duffy    NaN               1
# 2  Tamburello    NaN               0
# 3     Walters    NaN               0
# 4    Erickson    NaN               0
