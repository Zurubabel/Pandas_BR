# %%
# Importando o pandas e o numpy
import pandas as pd
import numpy as np

# %%
# Importando usando os
import os

# %%
pd.read_csv(os.getcwd() + "\\..\\..\\bases\\alugueis\\houses_to_rent.csv")
# Out:
#       Unnamed: 0  city  area  rooms  bathroom  parking spaces floor  \
# 0              0     1   240      3         3               4     -
# 1              1     0    64      2         1               1    10
# 2              2     1   443      5         5               4     3
# 3              3     1    73      2         2               1    12
# 4              4     1    19      1         1               0     -
# ...          ...   ...   ...    ...       ...             ...   ...
# 6075        6075     1    50      2         1               1     2
# 6076        6076     1    84      2         2               1    16
# 6077        6077     0    48      1         1               0    13
# 6078        6078     1   160      3         2               2     -
# 6079        6079     1    60      2         1               1     4
#
#          animal      furniture      hoa rent amount property tax  \
# 0         acept      furnished      R$0     R$8,000      R$1,000
# ...

# %%
# Combinando os e pathlib
from pathlib import Path

# %%
p = Path(os.getcwd())

# %%
pd.read_csv(str(p.parent.parent) + "\\bases\\alugueis\\houses_to_rent.csv")
# Out:
#       Unnamed: 0  city  area  rooms  bathroom  parking spaces floor  \
# 0              0     1   240      3         3               4     -
# 1              1     0    64      2         1               1    10
# 2              2     1   443      5         5               4     3
# 3              3     1    73      2         2               1    12
# 4              4     1    19      1         1               0     -
# ...          ...   ...   ...    ...       ...             ...   ...
# 6075        6075     1    50      2         1               1     2
# 6076        6076     1    84      2         2               1    16
# 6077        6077     0    48      1         1               0    13
# 6078        6078     1   160      3         2               2     -
# 6079        6079     1    60      2         1               1     4
#
#          animal      furniture      hoa rent amount property tax  \
# 0         acept      furnished      R$0     R$8,000      R$1,000
# ...
